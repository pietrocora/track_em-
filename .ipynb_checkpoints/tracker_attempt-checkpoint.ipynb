# %% [markdown]
# This code just attempts to identify features and track them using trackpy.

# %%
#import packages 

from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3
from time import time #time how long stuff takes 
import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 6))
mpl.rc('image', cmap='gray')

import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims #image manipulation
import trackpy as tp
import os #eh
import cv2 #for saving images 
import time
from trackpy import predict


#%%
path = "C:\\Users\\Kevin\\Desktop\\PhD\\lisboa\\23may\\four lights and white screen\\TimeAlignedFrames"
os.chdir(path)

prefix = "M_L-"

# %%
#okay just try the left video for now
start = 885
end = 2020
frames = pims.ImageSequence(prefix+"*.png")

# %%
n=1504

f = tp.locate(frames[n], 31, invert=False,minmass=2000)
plt.figure()  # make a new figure
tp.annotate(f, frames[n]);

# %%
features = tp.batch(frames[1500:1501], 31, minmass=2000, invert=False)
# Out:
# Frame 1500: 36 features

# %%
pred = trackpy.predict.NearestVelocityPredict() #this uses predictive linking based on learning 
tr = pred.link_df(features, 5,5)
# Out:
# Frame 1699: 32 trajectories present

# %%
#filter out trajectories with less than 50 pixels of movement 
tr1 = tp.filter_stubs(tr, 50)
# Compare the number of particles in the unfiltered and filtered data.
print('Before:', tr['particle'].nunique())
print('After:', tr1['particle'].nunique())
# Out:
# Before: 1335
# After: 23

# %%
#plot the trajectories 
plt.figure()
plt.xlim(xmin=0,xmax=1920)
plt.ylim(ymin=0,ymax=400)

ax = tp.plot_traj(tr1)

# %%
V = []
particles = tr1.particle.unique()
for p in particles: 
        pf=tr1[tr1.particle==p] #find the elements of tr1 corresponding to trajectory of particle p 
        pf0 = pf.iloc[[0],[0,1,-2]] #draw out the initial x,y, frame values over the trajectory of particle p 
        pfN = pf.iloc[[-1],[0,1,-2]] #draw out the final x,y,frame values over the trajectory of particle p 
        x0 = pf0.iat[0,0] #just gettting initial x,y,f values
        y0 = pf0.iat[0,1]
        f0 = pf0.iat[0,2]
        xN = pfN.iat[0,0] #and getting final x,y,f values 
        yN = pfN.iat[0,1]
        fN = pfN.iat[0,2]
        Dx = xN-x0 #x displacement
        Dy = yN-y0 #y displacement
        Df = fN-f0 #number of frames of trajectory 
        Dr = np.sqrt(Dx**2+Dy**2) #rms displacement over full path 
        v = Dr/Df*.02*190 #approximately the average velocity over the trajectory in cm/s
        V.append(v) #make an array of average velocities

# %%
V = V[V>0.2] #filter values below 0.2cm/s

# %%
V
# Out:
# array([  7.47811706,   8.73334484,  22.40425433,  25.8168034 ,
#         26.04871682,  17.70294943,  22.13139137,  31.68432942,
#         12.42465822,   6.9054449 ,   9.38495039])

# %%
V_avg = np.mean(V)

# %%
V_avg #mean velocity
# Out:
# 17.33772365254918

# %% [markdown]
# mean velocity is 17cm/s

# %% [markdown]
# Now try to get an example dataset for Pietro to match left and right frames with

# %%
#first find all features in the left set of images 
start = 885
end = 2020
prefix = "M_L-"
frames = pims.ImageSequence(prefix+"*.png")
print("Feature search began " + str(time.ctime()))
Lfeat = tp.batch(frames[start:end], 31, minmass=2000, invert=False)
Lfeat.to_pickle('Lfeat.pkl')  #save the features dataframe for later  
print(str(start-end) + " images searched for features in " + str((time.time()-t0)/60/60)+ " hours.")
print("Feature search ended "+ str(time.ctime()))
# Out:
# Frame 2019: 13 features
# -1135 images searched for features in 3.260876462923156 hours.
# Feature search ended Wed May 24 11:49:51 2017

# %%
#then find all features in the right set of images 
start = 885
end = 2020
prefix = "M_R-"
frames = pims.ImageSequence(prefix+"*.png")
print("Feature search began " + str(time.ctime()))
Rfeat = tp.batch(frames[start:end], 31, minmass=2000, invert=False)
Rfeat.to_pickle('Rfeat.pkl')  #save the features dataframe for later  
print(str(start-end) + " images searched for features in " + str((time.time()-t0)/60/60)+ " hours.")
print("Feature search ended "+ str(time.ctime()))
# Out:
# Frame 2019: 6 features
# -1135 images searched for features in 6.062886455721325 hours.
# Feature search ended Wed May 24 14:37:58 2017

# %%
pred = predict.NearestVelocityPredict() #this uses predictive linking based on learning 
Lt = pred.link_df(Lfeat, 5,5)
Rt = pred.link_df(Rfeat, 5,5)
# Out:
# Frame 2019: 6 trajectories present

# %%
Lt.to_pickle('Lt.pkl')
Rt.to_pickle('Rt.pkl')

# %%
#plot the trajectories 
plt.figure()
plt.xlim(xmin=0,xmax=1920)
plt.ylim(ymin=0,ymax=400)

ax = tp.plot_traj(Lt)

# %%
#plot the trajectories 
plt.figure()
plt.xlim(xmin=0,xmax=1920)
plt.ylim(ymin=0,ymax=400)

ax = tp.plot_traj(Rt)

# %%
#filter out trajectories with less than 50 pixels of movement 
Rt1 = tp.filter_stubs(Rt, 50)
Lt1 = tp.filter_stubs(Lt,50)

# %%
#plot the trajectories 
plt.figure()
plt.xlim(xmin=0,xmax=1920)
plt.ylim(ymin=0,ymax=400)

ax = tp.plot_traj(Lt1)

# %%
#plot the trajectories 
plt.figure()
plt.xlim(xmin=0,xmax=1920)
plt.ylim(ymin=0,ymax=400)

ax = tp.plot_traj(Rt1)

# %%
VL = []
particles = Lt1.particle.unique()
for p in particles: 
        pf=Lt1[Lt1.particle==p] #find the elements of tr1 corresponding to trajectory of particle p 
        pf0 = pf.iloc[[0],[0,1,-2]] #draw out the initial x,y, frame values over the trajectory of particle p 
        pfN = pf.iloc[[-1],[0,1,-2]] #draw out the final x,y,frame values over the trajectory of particle p 
        x0 = pf0.iat[0,0] #just gettting initial x,y,f values
        y0 = pf0.iat[0,1]
        f0 = pf0.iat[0,2]
        xN = pfN.iat[0,0] #and getting final x,y,f values 
        yN = pfN.iat[0,1]
        fN = pfN.iat[0,2]
        Dx = xN-x0 #x displacement
        Dy = yN-y0 #y displacement
        Df = fN-f0 #number of frames of trajectory 
        Dr = np.sqrt(Dx**2+Dy**2) #rms displacement over full path 
        v = Dr/Df*.02*190 #approximately the average velocity over the trajectory in cm/s
        VL.append(v) #make an array of average velocities 
VL = np.array(VL)
VL = VL[VL>0.2]        
plt.hist(VL,bins=20)
# Out:
# (array([ 13.,   0.,   1.,   4.,   4.,   4.,   6.,   1.,   6.,   5.,   7.,
#           3.,   5.,   2.,   2.,   3.,   1.,   0.,   1.,   1.]),
#  array([  0.20412674,   2.27224662,   4.3403665 ,   6.40848638,
#           8.47660626,  10.54472614,  12.61284602,  14.6809659 ,
#          16.74908578,  18.81720566,  20.88532554,  22.95344542,
#          25.0215653 ,  27.08968518,  29.15780506,  31.22592494,
#          33.29404482,  35.3621647 ,  37.43028458,  39.49840446,  41.56652434]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(VL,bins=20)
# Out:
# (array([ 13.,   0.,   1.,   4.,   4.,   4.,   6.,   1.,   6.,   5.,   7.,
#           3.,   5.,   2.,   2.,   3.,   1.,   0.,   1.,   1.]),
#  array([  0.20412674,   2.27224662,   4.3403665 ,   6.40848638,
#           8.47660626,  10.54472614,  12.61284602,  14.6809659 ,
#          16.74908578,  18.81720566,  20.88532554,  22.95344542,
#          25.0215653 ,  27.08968518,  29.15780506,  31.22592494,
#          33.29404482,  35.3621647 ,  37.43028458,  39.49840446,  41.56652434]),
#  <a list of 20 Patch objects>)

# %%
VR = []
particles = Rt1.particle.unique()
for p in particles: 
        pf=Rt1[Rt1.particle==p] #find the elements of tr1 corresponding to trajectory of particle p 
        pf0 = pf.iloc[[0],[0,1,-2]] #draw out the initial x,y, frame values over the trajectory of particle p 
        pfN = pf.iloc[[-1],[0,1,-2]] #draw out the final x,y,frame values over the trajectory of particle p 
        x0 = pf0.iat[0,0] #just gettting initial x,y,f values
        y0 = pf0.iat[0,1]
        f0 = pf0.iat[0,2]
        xN = pfN.iat[0,0] #and getting final x,y,f values 
        yN = pfN.iat[0,1]
        fN = pfN.iat[0,2]
        Dx = xN-x0 #x displacement
        Dy = yN-y0 #y displacement
        Df = fN-f0 #number of frames of trajectory 
        Dr = np.sqrt(Dx**2+Dy**2) #rms displacement over full path 
        v = Dr/Df*.02*190 #approximately the average velocity over the trajectory in cm/s
        VR.append(v) #make an array of average velocities 
VR = np.array(VR)
VL = VR[VR>0.2]        
plt.hist(VR,bins=20)
# Out:
# (array([ 25.,   1.,   1.,   1.,   4.,   2.,   3.,   1.,   2.,   5.,   0.,
#           8.,   4.,   1.,   2.,   2.,   1.,   1.,   2.,   2.]),
#  array([  2.02154361e-03,   1.67173639e+00,   3.34145123e+00,
#           5.01116607e+00,   6.68088092e+00,   8.35059576e+00,
#           1.00203106e+01,   1.16900254e+01,   1.33597403e+01,
#           1.50294551e+01,   1.66991700e+01,   1.83688848e+01,
#           2.00385997e+01,   2.17083145e+01,   2.33780293e+01,
#           2.50477442e+01,   2.67174590e+01,   2.83871739e+01,
#           3.00568887e+01,   3.17266036e+01,   3.33963184e+01]),
#  <a list of 20 Patch objects>)
